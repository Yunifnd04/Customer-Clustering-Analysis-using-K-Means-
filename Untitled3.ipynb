# %%
#Import Package
import pandas as pd

# %%
# Dataset
df = pd.read_csv("marketing_clean.csv", sep='\t')

df.head()
# Out:
#     Education Marital_Status  Income  Kidhome  Teenhome  Recency  MntWines  \
# 0  Graduation       Together   71613        0         0       26       426
# 1  Graduation       Together   26646        1         0       26        11
# 2         PhD        Married   58293        1         0       94       173
# 3      Master       Together   62513        0         1       16       520
# 4  Graduation       Divorced   55635        0         1       34       235
#
#    MntFruits  MntMeatProducts  MntFishProducts  ...  NumCatalogPurchases  \
# 0         49              127              111  ...                    2
# 1          4               20               10  ...                    0
# 2         43              118               46  ...                    3
# 3         42               98                0  ...                    4
# 4         65              164               50  ...                    3
#
#    NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  \
# ...

# %%
#Cek tipe data
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1654 entries, 0 to 1653
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Education            1654 non-null   object
#  1   Marital_Status       1654 non-null   object
#  2   Income               1654 non-null   int64
#  3   Kidhome              1654 non-null   int64
#  4   Teenhome             1654 non-null   int64
#  5   Recency              1654 non-null   int64
#  6   MntWines             1654 non-null   int64
#  7   MntFruits            1654 non-null   int64
#  8   MntMeatProducts      1654 non-null   int64
#  9   MntFishProducts      1654 non-null   int64
#  10  MntSweetProducts     1654 non-null   int64
#  11  MntGoldProds         1654 non-null   int64
#  12  NumDealsPurchases    1654 non-null   int64
#  13  NumWebPurchases      1654 non-null   int64
#  14  NumCatalogPurchases  1654 non-null   int64
# ...

# %%
#Cek ulang data kosong
df.isnull().sum()
# Out:
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Complain               0
# age                    0
# dtype: int64

# %%
#Standarisasi Data

from sklearn.preprocessing import StandardScaler

X = df.select_dtypes(include ='number')

scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
#Clustering K-Means

from sklearn.cluster import KMeans

#jumlah cluster
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(X_scaled)

# %%
#Hasil Clustering

df['Cluster'].value_counts()
df.groupby('Cluster').mean(numeric_only=True)
# Out:
#                Income   Kidhome  Teenhome    Recency    MntWines  MntFruits  \
# Cluster
# 0        81113.288462  0.057692  0.134615  47.602564  792.480769  58.737179
# 1        35323.352321  0.805907  0.424051  48.374473   60.007384   5.533755
# 2        67358.429091  0.130909  0.578182  49.972727  511.694545  50.910909
#
#          MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  \
# Cluster
# 0             484.666667        83.275641         67.032051     77.608974
# 1              29.182489         7.939873          5.690928     19.056962
# 2             287.405455        69.409091         49.338182     71.300000
#
#          ...  NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  \
# Cluster  ...
# 0        ...             5.987179           8.333333           3.141026
# 1        ...             0.655063           3.434599           6.598101
# 2        ...             4.545455           8.541818           4.301818
#
# ...

# %%
df.to_csv("clustered_customers.csv", index=False)

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_data = pca.fit_transform(X_scaled)

plt.figure(figsize=(8,6))
plt.scatter(pca_data[:, 0], pca_data[:, 1], c=clusters, cmap='viridis')
plt.title("Visualisasi Clustering (PCA)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

# %%
#Distribusi nilai per Cluster
#Income
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=df, x='Cluster', y='Income', palette='Set2')
plt.title('Distribusi Income per Cluster')
plt.show()
# Out:
# /tmp/ipython-input-15-1924021957.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Cluster', y='Income', palette='Set2')

# %%
#Distribusi nilai per Cluster
#Income
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=df, x='Cluster', y='MntWines', palette='Set2')
plt.title('Distribusi MntWines per Cluster')
plt.show()
# Out:
# /tmp/ipython-input-19-4294738159.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Cluster', y='MntWines', palette='Set2')

# %%
#Distribusi nilai per Cluster
#Income
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=df, x='Cluster', y='MntMeatProducts', palette='Set2')
plt.title('Distribusi MntMeatProducts per Cluster')
plt.show()
# Out:
# /tmp/ipython-input-20-1545766901.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Cluster', y='MntMeatProducts', palette='Set2')

# %%
#Distribusi nilai per Cluster
#Income
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=df, x='Cluster', y='MntFruits', palette='Set2')
plt.title('Distribusi MntFruits per Cluster')
plt.show()
# Out:
# /tmp/ipython-input-21-2730644233.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Cluster', y='MntFruits', palette='Set2')

# %%
#Distribusi nilai per Cluster
#Income
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=df, x='Cluster', y='MntFishProducts', palette='Set2')
plt.title('Distribusi MntFishProducts per Cluster')
plt.show()
# Out:
# /tmp/ipython-input-22-4225720014.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Cluster', y='MntFishProducts', palette='Set2')

# %%
#Distribusi nilai per Cluster
#Income
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=df, x='Cluster', y='MntSweetProducts', palette='Set2')
plt.title('Distribusi MntSweetProducts per Cluster')
plt.show()
# Out:
# /tmp/ipython-input-23-3886119650.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Cluster', y='MntSweetProducts', palette='Set2')

# %%
#Distribusi nilai per Cluster
#Income
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=df, x='Cluster', y='MntGoldProds', palette='Set2')
plt.title('Distribusi MntGoldProds per Cluster')
plt.show()
# Out:
# /tmp/ipython-input-24-576721429.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Cluster', y='MntGoldProds', palette='Set2')

# %%
sns.countplot(data=df, x='Cluster', palette='pastel')
plt.title('Jumlah Pelanggan per Cluster')
plt.show()
# Out:
# /tmp/ipython-input-27-1464334663.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Cluster', palette='pastel')
